# %%
import requests
import pandas as pd
import json

# %%
url = "https://api.covid19api.com/total/country/argentina/status/confirmed?from=2020-03-01T00:00:00Z&to=2022-04-01T00:00:00Z"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)

data = pd.read_json(response.text)
data.head()
# Out:
# [{"Country":"Argentina","CountryCode":"","Province":"","City":"","CityCode":"","Lat":"0","Lon":"0","Cases":0,"Status":"confirmed","Date":"2020-03-01T00:00:00Z"},{"Country":"Argentina","CountryCode":"","Province":"","City":"","CityCode":"","Lat":"0","Lon":"0","Cases":0,"Status":"confirmed","Date":"2020-03-02T00:00:00Z"},{"Country":"Argentina","CountryCode":"","Province":"","City":"","CityCode":"","Lat":"0","Lon":"0","Cases":1,"Status":"confirmed","Date":"2020-03-03T00:00:00Z"},{"Country":"Argentina","CountryCode":"","Province":"","City":"","CityCode":"","Lat":"0","Lon":"0","Cases":1,"Status":"confirmed","Date":"2020-03-04T00:00:00Z"},{"Country":"Argentina","CountryCode":"","Province":"","City":"","CityCode":"","Lat":"0","Lon":"0","Cases":1,"Status":"confirmed","Date":"2020-03-05T00:00:00Z"},{"Country":"Argentina","CountryCode":"","Province":"","City":"","CityCode":"","Lat":"0","Lon":"0","Cases":2,"Status":"confirmed","Date":"2020-03-06T00:00:00Z"},{"Country":"Argentina","CountryCode":
# ...

# %% [markdown]
# No estoy seguro, pero no fue las mas llamativa de hacer. Si fue la mas interesante, pero no entiendo bien como se almacena la informacion.
